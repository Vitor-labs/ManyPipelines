# %%
import pandas as pd

pd.set_option("display.max_columns", None)

DF_FMD = pd.read_csv("./WarrantyFMD_sample.csv", index_col=0)
DF_GSAR = pd.read_csv("./WarrantyGSAR_sample.csv", index_col=0)

# %%
DF_GSAR.head()
# Out:
#        Model Year  Model Year (Fixed)  Model Year (Sales)  \
# 18289        2022                2022                2022
# 21779        2022                2022                2022
# 17504        2022                2022                2022
# 27202        2023                2023                2023
# 3278         2020                2020                2020
#
#        Model Year (Manufacturing)                VIN  Claim Key  \
# 18289                        2022  3FMTK3SU8NMA38066    2781006
# 21779                        2022  3FMTK4SX4NMA13486    2878357
# 17504                        2022  3FMTK1RM5NMA34566    3948632
# 27202                        2023  3FMTK3RM9PMA33290     720434
# 3278                         2020  1FM5K8AW2LGC65995   12465610
#
#       Vehicle Line Global              Vehicle Line Global Desc  \
# 18289                  HP        MACH E (CX727) (NA-CUAUTITLAN)
# 21779                  HP        MACH E (CX727) (NA-CUAUTITLAN)
# ...
